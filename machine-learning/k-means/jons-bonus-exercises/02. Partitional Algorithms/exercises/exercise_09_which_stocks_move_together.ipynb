# %% [markdown]
# # Exercise 9: Which stocks move together?
#
# In the previous exercise, you clustered companies by their daily stock price movements.  So which company have stock prices that tend to change in the same way?  Now inspect the cluster labels from your clustering to find out.

# %% [markdown]
# **Step 1:** Load the data _(written for you)_.

# %%
import pandas as pd

fn = '../datasets/company-stock-movements-2010-2015-incl.csv'
stocks_df = pd.read_csv(fn, index_col=0)

# %% [markdown]
# **Step 2:** Run your code from the previous exercise _(filled in for you)_.

# %%
companies = list(stocks_df.index)
movements = stocks_df.values

from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline

normalizer = Normalizer()
kmeans = KMeans(n_clusters=14)
pipeline = make_pipeline(normalizer, kmeans)
pipeline.fit(movements)
# Out:
# Pipeline(steps=[('normalizer', Normalizer()),
#                 ('kmeans', KMeans(n_clusters=14))])

# %% [markdown]
# **Step 3:** Use the `.predict()` method of the pipeline to predict the labels for `movements`.

# %%
labels = pipeline.predict(movements)

# %% [markdown]
# **Step 4:** Align the cluster labels with the list of company names `companies` by creating a DataFrame `df` with `labels` and `companies` as columns.

# %%
df = pd.DataFrame()
df["companies"] = companies
df["labels"] = labels

# %% [markdown]
# **Step 5:** Now display the DataFrame, sorted by cluster label.  To do this, use the `.sort_values()` method of `df` to sort the DataFrame by the `'labels'` column.

# %%
df.sort_values("labels")
# Out:
#                              companies  labels
# 50  Taiwan Semiconductor Manufacturing       0
# 51                   Texas instruments       0
# 33                           Microsoft       0
# 11                               Cisco       0
# 22                                  HP       0
# 24                               Intel       0
# 15                                Ford       1
# 18                       Goldman Sachs       1
# 5                      Bank of America       1
# 55                         Wells Fargo       1
# 1                                  AIG       1
# 26                      JPMorgan Chase       1
# 19                     GlaxoSmithKline       2
# 46                      Sanofi-Aventis       2
# 43                                 SAP       3
# 42                   Royal Dutch Shell       3
# 49                               Total       3
# 37                            Novartis       3
# 52                            Unilever       3
# 6             British American Tobacco       3
# 40                      Procter Gamble       4
# 56                            Wal-Mart       4
# 25                   Johnson & Johnson       4
# 9                    Colgate-Palmolive       4
# 27                      Kimberly-Clark       4
# 7                                Canon       5
# 45                                Sony       5
# 21                               Honda       5
# 34                          Mitsubishi       5
# 48                              Toyota       5
# 17                     Google/Alphabet       6
# 0                                Apple       6
# 10                      ConocoPhillips       7
# 53                       Valero Energy       7
# 44                        Schlumberger       7
# 12                             Chevron       7
# 57                               Exxon       7
# 35                            Navistar       7
# 59                               Yahoo       8
# 2                               Amazon       8
# 29                     Lookheed Martin       9
# 36                    Northrop Grumman       9
# 3                     American express      10
# 4                               Boeing      10
# 8                          Caterpillar      10
# 13                   DuPont de Nemours      10
# 14                                Dell      10
# 16                   General Electrics      10
# 20                          Home Depot      10
# 47                            Symantec      10
# 58                               Xerox      10
# 30                          MasterCard      10
# 32                                  3M      10
# 23                                 IBM      10
# 54                            Walgreen      11
# 39                              Pfizer      12
# 38                               Pepsi      13
# 28                           Coca Cola      13
# 31                           McDonalds      13
# 41                       Philip Morris      13

# %% [markdown]
# **Great job!** Using k-means, you've discovered which companies stock prices move together on the stock exchange.

# %%
# Nice, we have grouped the companies together, using data we can see which companies have similarities!
# E.g. Pepsi, Coke, McDs, Phillip Morris. All unhealthy stuff, Soda, Fast Food and Cigarettes
